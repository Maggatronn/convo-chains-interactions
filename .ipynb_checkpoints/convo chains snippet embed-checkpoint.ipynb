# %%
import os
import json
import csv
import re
import pandas as pd
import sentence_transformers
import umap.umap_ as umap
import matplotlib.pyplot as plt
import altair as alt
import langdetect 
import numpy as np
# import multiprocessing

# %%
model = sentence_transformers.SentenceTransformer('all-mpnet-base-v2', device="cpu")

# %%
convos = pd.read_json('./conversation_lists.json')
convos.head()
# Out:
#                                           collection  duration  host_id    id
# 0  {'description': '<p>This collection features o...  5581.620     5227  1722  \
# 1  {'description': '<p>This collection features o...  4881.276     5227  1723
# 2  {'description': '<p>This collection features o...  4244.544     5227  1724
# 3  {'description': '<p>This collection features o...  4883.868     5227  1726
# 4  {'description': '<p>This collection features o...  3166.248     5227  1733
#
#    is_draft language_codes                                           location
# 0     False        [en-US]  {'lng_lat': [-69.78455, 44.39996], 'name': 'Ke...  \
# 1     False        [en-US]  {'lng_lat': [-69.78455, 44.39996], 'name': 'Ke...
# 2     False        [en-US]  {'lng_lat': [-69.2365510393463, 45.3982848479]...
# 3     False        [en-US]  {'lng_lat': [-69.2365510393463, 45.3982848479]...
# 4     False        [en-US]  {'lng_lat': [-69.2365510393463, 45.3982848479]...
#
# ...

# %%
convo_id_list= []
for i in range(0, len(convos)):
#     print(convos["collection"][i]['title'])
    if convos["collection"][i]['title'] == "Real Talk for Change ":
        convo_id_list.append(convos['id'][i])
len(convo_id_list)
# # PFC = pd.read_csv('./PFC.csv')
# # PFC.head()
# Out:
# 45

# %%
# convo_id_list = []
# for i in range(0, len(convos)):
#     convo_id_list.append(convos['id'][i])
# print (convo_id_list)

# len(convo_id_list)

# %%
file_list = []
for i in convo_id_list: 
    file_list.append("./output2/conversation-" + str(i) + ".json")

# %%
file_list
# Out:
# ['./output2/conversation-1378.json',
#  './output2/conversation-1379.json',
#  './output2/conversation-1380.json',
#  './output2/conversation-1382.json',
#  './output2/conversation-1403.json',
#  './output2/conversation-1406.json',
#  './output2/conversation-1407.json',
#  './output2/conversation-1412.json',
#  './output2/conversation-1413.json',
#  './output2/conversation-1414.json',
#  './output2/conversation-1434.json',
#  './output2/conversation-1441.json',
#  './output2/conversation-1442.json',
#  './output2/conversation-1446.json',
#  './output2/conversation-1447.json',
#  './output2/conversation-1463.json',
#  './output2/conversation-1464.json',
#  './output2/conversation-1465.json',
#  './output2/conversation-1466.json',
#  './output2/conversation-1478.json',
#  './output2/conversation-1483.json',
#  './output2/conversation-1484.json',
#  './output2/conversation-1489.json',
#  './output2/conversation-1490.json',
#  './output2/conversation-1495.json',
# ...

# %%
# dict_keys(['collection', 'duration', 'highlights', 'host_id', 'id', 'is_draft', 
# 'language_codes', 'location', 'participant_postal_codes', 'participants', 
# 'privacy_level', 'snippets', 'start_time', 'title'])

snippet_ids = []
proportional_local = []
conversation = []
words = []
speaker = []
collection = []


for i in file_list:
    f = open(i)
#     file_name = i.split("/")[-1]
    file = json.load(f)
#     print(file['snippets'])
    for snippet in file['snippets']:
        word_list = ""
        for word in snippet['words']:
            word_list += word[0] + " "            
        try:
            language = langdetect.detect(word_list)
        except:
            language = "error"
            print("This row throws and error:", word_list)
        if language == "en":
            words.append(word_list)
            snippet_ids.append(snippet['id'])
            conversation.append(snippet['conversation_id'])
            speaker.append(snippet['speaker_name'])
            proportional_local.append(snippet['index_in_conversation']/len(file['snippets']))
# Out:
# This row throws and error: 14.
# This row throws and error: Yes.
# This row throws and error: Thank you Reggie. Miss Sarah, could you please check in and physically, intellectually, emotionally or spiritually?
# This row throws and error: Well, I also live in Cambridge.
# This row throws and error: 41,000.
# This row throws and error: 365.

# %%
collection_dict = {}

for i in file_list:
    f = open(i)
#     file_name = i.split("/")[-1]
    file = json.load(f)
    collection_dict[file['id']] = file['collection']["id"]
# collection_dict    
#     if file['collection']["id"] not in collection_dict.keys():
#         collection_dict[file['collection']["id"]] = [file['id']]
#     else:
#         collection_dict[file['collection']["id"]].append(file['id'])
#     print(file['collection']["id"])

collection_ids = []
for i in range(0, len(conversation)):
    collection_ids.append(collection_dict[conversation[i]])
collection_ids
# Out:
# [114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
# ...

# %%
len(collection_ids)
# Out:
# 6302

# %%
print(len(snippet_ids), len(speaker), len(conversation), len(words), len(proportional_local))


for i in range(0, len(collection_ids)):
    if i == 114:
        print(i)
# Out:
# 6302 6302 6302 6302 6302
# 114

# %%
conv_ids, texts = zip(*((snippet_ids[i], words[i]) for i in range(0, len(words))))
embeddings = model.encode(texts,show_progress_bar=True)
embeddings
# Out:
# Batches:   0%|          | 0/197 [00:00<?, ?it/s]
# array([[ 0.02736891,  0.12164803, -0.00345966, ..., -0.00889667,
#         -0.03961252, -0.02183418],
#        [-0.04673749,  0.09666345, -0.01063121, ..., -0.01426727,
#          0.01314355, -0.00514111],
#        [ 0.06607319,  0.04779887, -0.01952492, ...,  0.0056567 ,
#         -0.03049325, -0.00476172],
#        ...,
#        [ 0.02949797,  0.07321663,  0.02238022, ...,  0.04385904,
#         -0.04655191, -0.00102145],
#        [ 0.05529347,  0.05787767,  0.01199968, ...,  0.02942703,
#          0.02320703,  0.00490539],
#        [-0.00263279,  0.0467316 ,  0.01437661, ...,  0.0015583 ,
#         -0.00016216, -0.01412145]], dtype=float32)

# %%
len(embeddings), len(words)
# Out:
# (6302, 6302)

# %%
reducer = umap.UMAP(n_components=2)

# %%
# scaled_data = StandardScaler().fit_transform(embeddings)

# %%
embedding_reduce = reducer.fit_transform(embeddings)
embedding_reduce.shape
# Out:
# (6302, 2)

# %%
len(embedding_reduce), len(words)
# Out:
# (6302, 6302)

# %%
nodes = []
edges = []
rootxlist = []
rootylist = []
convo_list = []
convo_index_list = []
numpyarray = []
past_convo = 0
# len(speaker), len(words)
for i in range(0, len(words)):
    current_convo = conversation[i]
    if i == 1:
        past_convo = current_convo
    current_id = str(snippet_ids[i])[len(str(current_convo)):len(str(snippet_ids[i]))]
    x = embedding_reduce[i][0]
    y = embedding_reduce[i][1]
    embedding = embeddings[i]
    collection = collection_ids[i]
    current_prop = proportional_local[i]
    node_id = int((str(current_convo) + "00" + str(current_id)))
    current_speaker = speaker[i]
    word = words[i]
    if collection == 114:
        if past_convo == current_convo:
            edges.append({
                "source": str(nodes[-1]["id"]),
                "target": str(node_id),
                "collection": str(collection)
            })
        nodes.append({
            "id": int(node_id),
            "conversation": str(current_convo),
            "convo_index": str(current_id),
            "rootx": float(translate(x, -7.5, 18, 0, 1500)),
            "rooty": float(translate(y, -2.75, 10, 0, 900)),   
            "speaker": str(current_speaker),
            "collection": str(collection),
            "convo_prop_index": float(current_prop),
            "words": str(word)
        })
        
#         first_array = np.insert(embedding, 0, int(current_convo))
#         second_array = np.insert(first_array, 1, int(current_id))
#         numpyarray.append(second_array)
#         print(embedding)
        convo_index_list.append(current_id)
        if current_convo not in convo_list:
            convo_list.append(current_convo)
        rootxlist.append(x)        
        rootylist.append(y)    
        past_convo = current_convo

master_network_dict = {
    'nodes': nodes,
    'edges': edges
}
print(min(rootxlist), max(rootxlist))
print(min(rootylist), max(rootylist))
print(min(convo_list), max(convo_list))
print(min(proportional_local), max(proportional_local))
# print(len(convo_list))dd
# print(nodes)
# Out:
# -7.200016 17.648478
# -2.5426898 9.601977
# 1378 2838
# 0.0 0.9968652037617555

# %%
with open('./rtfc_embed_list_full_2d.json', 'w') as f:
    json.dump(master_network_dict, f)

# %%
# convert array into dataframe
DF = pd.DataFrame(numpyarray)
 
# save the dataframe as a csv file
DF.to_csv("array.csv")

# %%
def translate(value, leftMin, leftMax, rightMin, rightMax):
    # Figure out how 'wide' each range is
    leftSpan = leftMax - leftMin
    rightSpan = rightMax - rightMin

    # Convert the left range into a 0-1 range (float)
    valueScaled = float(value - leftMin) / float(leftSpan)

    # Convert the 0-1 range into a value in the right range.
    return rightMin + (valueScaled * rightSpan)

# %%
nodes = []
edges = []
rootxlist = []
rootylist = []
convo_list = []
convo_index_list = []
past_convo = 0
for i in range(0, len(words)):
    current_convo = conversation[i]
    if i == 1:
        past_convo = current_convo
    current_id = str(snippet_ids[i])[len(str(current_convo)):len(str(snippet_ids[i]))]
    x = embedding_reduce[i][0]
    y = embedding_reduce[i][1]
    collection = collection_ids[i]
    current_prop = proportional_local[i]
    node_id = int((str(current_convo) + "00" + str(current_id)))
    speaker = data["speaker_name"][i]
    word = words[i]
    if collection == 114:
        if past_convo == current_convo:
            edges.append({
                "source": nodes[-1]["id"],
                "target": node_id,
                "collection": collection
            })
        nodes.append({
            "id": int(node_id),
            "conversation": int(current_convo),
            "convo_index": int(current_id),
            "rootx": float(translate(x, -4.899243, 6.6633325, 0, 1200)),
            "rooty": float(translate(y, -3.5679097, 6.074352, 0, 900)),        
            "speaker": str(speaker),
            "collection": collection,
            "convo_prop_index": current_prop,
            "words": word
        })
        convo_index_list.append(current_id)
        if current_convo not in convo_list:
            convo_list.append(current_convo)
        rootxlist.append(x)        
        rootylist.append(y)    
        past_convo = current_convo

master_network_dict = {
    'nodes': nodes,
    'edges': edges
}
print(min(rootxlist), max(rootxlist))
print(min(rootylist), max(rootylist))
print(min(convo_list), max(convo_list))
print(min(proportional_local), max(proportional_local))
print(len(convo_list))
# Out:
# -4.8059497 7.148416
# -3.8212814 5.9730473
# 5 3028
# 0.0 0.9978165938864629
# 416

# %%
with open('./multi_set.json', 'w') as f:
    json.dump(master_network_dict, f)

# %%
# embedding_reduce, snippet_ids, conversation, words

# %%
dictionary = []
for i in range(0, len(words)-1):
    dictionary.append({
        "x": embedding_reduce[i][0],
        "y": embedding_reduce[i][1],
        "id": snippet_ids[i],
        "conversation": conversation[i],
        "words": words[i]
    })
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[90], line 4
#       1 dictionary = []
#       2 for i in range(0, len(words)-1):
#       3     dictionary.append({
# ----> 4         "x": embedding_reduce[i][0],
#       5         "y": embedding_reduce[i][1],
#       6         "id": snippet_ids[i],
#       7         "conversation": conversation[i],
#       8         "words": words[i]
#       9     })
#
# IndexError: index 57585 is out of bounds for axis 0 with size 57585

# %%
# Serializing json
json_object = json.dumps(dictionary, indent=4)
 
# Writing to sample.json
with open("sample.json", "w") as outfile:
    outfile.write(json_object)

# %%
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(embedding_reduce)

# %%
kmeans = KMeans(
            init="random",
            n_clusters=3,
            n_init=10,
            max_iter=300,
            random_state=42
         )

# %%
kmeans.fit(scaled_features)
# Out:
# KMeans(init='random', n_clusters=3, n_init=10, random_state=42)

# %%
kmeans.labels_[:5]
# Out:
# array([0, 0, 0, 0, 2], dtype=int32)

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "max_iter": 500,
    "random_state": 42,
}
# A list holds the SSE values for each k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    sse.append(kmeans.inertia_)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kl = KneeLocator(
   range(1, 11), sse, curve="convex", direction="decreasing"
)

kl.elbow
# Out:
# 3

# %%
# A list holds the silhouette coefficients for each k
silhouette_coefficients = []

# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(2, 11), silhouette_coefficients)
plt.xticks(range(2, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %%
kmeans = KMeans(
            init="random",
            n_clusters=9,
            n_init=10,
            max_iter=300,
            random_state=42
         )
kmeans
# Out:
# KMeans(init='random', n_clusters=9, n_init=10, random_state=42)

# %%
# mh = pd.read_csv ('./Maggie.csv')
# mr1 = pd.read_csv ('./Mari 1.csv')
# mr2 = pd.read_csv ('./Mari 2.csv')
# tibi = pd.read_csv ('./Tibi.csv')
# dd = pd.read_csv ('./Dimitra.csv')




df = pd.concat(
    map(pd.read_csv, ['./Maggie.csv', './Dimitra.csv', './Mari 1.csv', './Mari 2.csv', './Tibi.csv']), ignore_index=True)

df[0:5]
# Out:
#    conversation_set_id conversation_set_name  conversation_id  \
# 0                   79      Current - Maggie             1403
# 1                   79      Current - Maggie             1403
# 2                   79      Current - Maggie             1403
# 3                   79      Current - Maggie             1403
# 4                   79      Current - Maggie             1403
#
#   conversation_date  highlight_id  highlight_start  highlight_end  \
# 0        2021-08-16       3154382           1371.0         1374.4
# 1        2021-08-16       3154382           1371.0         1374.4
# 2        2021-08-16       3154382           1371.0         1374.4
# 3        2021-08-16       3154382           1371.0         1374.4
# 4        2021-08-16       3154383           1377.8         1453.2
#
#   highlight_author                              highlight_description  \
# 0    Maggie Hughes  Don's question on housing and affordability (o...
# ...

# %%
parent_list = []
child_list = []
parent_dict = []
child_dict = []

highlight_list = []
links_dict= []

parent_count = 0
child_count = 0


past_highlight = 0
child_tag_list = []
parent_tag_list = []
highlights_list = []
highlights_tags_dict = []               

# creating highlights_tags_dict -- meaning each entry ius a highlight with a list of parent 
# and child tags associated, along with words and speaker


for num in range(0, len(df)):
    if isinstance(df['tag_title'][num], str):
        highlight = df['highlight_id'][num]
        speaker = df['highlight_speakers'][num]
        words = df['highlight_words'][num]
        parent_tag = df['tag_title'][num].split(".")[0]
        child_tag = df['tag_title'][num]    
        if num > 0:
            past_highlight = df['highlight_id'][num-1]

        if highlight == past_highlight:
            child_tag_list.append(child_tag)
            if "identity of speaker" in parent_tag:
                 identity_tag = child_tag
            if "type of highlight" in parent_tag:
                 type_tag = child_tag
            if parent_tag not in parent_tag_list: 
                parent_tag_list.append(parent_tag)
            if past_highlight not in highlights_list:
                highlights_tags_dict.append({
                    "highlight_id": past_highlight,                    
                    "parent_tag_list": parent_tag_list,
                    "child_tag_list": child_tag_list,
                    "speaker": speaker,
                    "words" : words, 
                    "type": type_tag,
                    "identity of speaker": identity_tag,
                    "identity of others": identity_others_tag
                })
                highlights_list.append(past_highlight)
        else:         
            child_tag_list = []
            parent_tag_list = []
            identity_tag = ''
            type_tag = ''
            identity_others_tag = ''
            if "identity of speaker" in parent_tag:
                 identity_tag = child_tag
            if "type of highlight" in parent_tag:
                 type_tag = child_tag
            if parent_tag not in parent_tag_list: 
                parent_tag_list.append(parent_tag)
            child_tag_list.append(child_tag)
            parent_tag_list.append(parent_tag)


        
parent_dict = {}
child_dict = {}

# for highlight in highlights_tags_dict: 
#     for tag in highlights_tags_dict[highlight]['parent_tag_list']:
#         parent_dict[int(highlight)] = highlights_tags_dict[highlight]

# print(highlights_tags_dict)

# %%
highlights_tags_dict
# Out:
# [{'highlight_id': 3154382,
#   'parent_tag_list': ['*type of highlight',
#    '*type of highlight',
#    'housing',
#    'economic opportunity',
#    '*identity of others'],
#   'child_tag_list': ['*type of highlight.question',
#    'housing.housing affordability',
#    'economic opportunity.income',
#    '*identity of others.class'],
#   'speaker': 'Don',
#   'words': 'how are most people going to ever afford to live in this city?',
#   'type': '*type of highlight.question',
#   'identity of speaker': '',
#   'identity of others': ''},
#  {'highlight_id': 3154383,
#   'parent_tag_list': ['*type of highlight',
#    '*type of highlight',
#    '*special features',
#    'housing',
#    'inequality'],
#   'child_tag_list': ['*type of highlight.experience',
#    '*special features.neigborhood mentioned',
#    'housing.homeownership',
#    'housing.gentrification and displacement',
#    'housing.housing affordability',
#    'inequality.class-based'],
#   'speaker': 'Don',
# ...

# %%
highlights_tags_dict_clean = []
for i in highlights_tags_dict:
#     print(i)
    if langdetect.detect(i["words"]) == "en" and len(i["words"].split(" ")) > 10:
        highlights_tags_dict_clean.append(i)

print(len(highlights_tags_dict), len(highlights_tags_dict_clean))
# Out:
# 1122 1077

# %%
conv_ids, texts = zip(*((x["highlight_id"], x["words"]) for x in highlights_tags_dict_clean if len(x["words"].split(" ")) > 10))
embeddings = model.encode(texts,show_progress_bar=True)
embeddings
# Out:
# Batches:   0%|          | 0/34 [00:00<?, ?it/s]
# array([[-0.03293911,  0.09597249,  0.01992808, ..., -0.01112545,
#          0.03390255,  0.00580797],
#        [-0.08126359,  0.08990652,  0.0313894 , ..., -0.00973798,
#          0.0470116 ,  0.02629041],
#        [ 0.01381874,  0.09332262, -0.0069167 , ..., -0.01201006,
#          0.05457805,  0.03315223],
#        ...,
#        [-0.07190071,  0.0954513 ,  0.01947739, ..., -0.00612847,
#          0.04854171, -0.00168589],
#        [-0.03626706,  0.07588849, -0.01311757, ...,  0.02706565,
#          0.01789846,  0.0434407 ],
#        [-0.03608556,  0.14752914,  0.00166503, ..., -0.03177502,
#         -0.01363057,  0.02399297]], dtype=float32)
